# %%
import pandas as pd
import os, sys
import glob
import numpy as np

# %%
path = "csse_covid_19_data/csse_covid_19_daily_reports"
all_files = glob.glob(path + "/*.csv")
li = []
for filename in all_files:
    df = pd.read_csv(filename, encoding="ISO-8859-1")
    li.append(df)
    frame = pd.concat(li, axis=0, ignore_index=True, sort=False)

# %%
frame.count()
# Out:
# Province/State     4358
# Country/Region     7617
# Last Update        7617
# Confirmed         56785
# Deaths            56363
# Recovered         56416
# FIPS              44680
# Admin2            45054
# Province_State    46424
# Country_Region    49187
# Last_Update       49187
# Lat               48901
# Long_             48901
# Active            49187
# Combined_Key      49187
# Latitude           4799
# Longitude          4799
# dtype: int64

# %%
df = frame
df = df.fillna('')
df['Province_State'] = df['Province/State'].astype(str) + df['Province_State'].astype(str)
df['Country_Region'] = df['Country/Region'].astype(str) + df['Country_Region'].astype(str)
df['Last_Update'] = df['Last Update'].astype(str) + df['Last_Update'].astype(str)
df['Latitude'] = df['Latitude'].astype(str) + df['Lat'].astype(str)
df['Longitude'] = df['Longitude'].astype(str) + df['Long_'].astype(str)
df = df.drop(columns=['Province/State','Country/Region','Last Update','Lat','Long_','Combined_Key'])
df['Last_Update'] = df['Last_Update'].str[0:10]
df = df.sort_values(by=['Country_Region','Last_Update'])
df.drop_duplicates(keep='first', inplace=True)
df = df[['Last_Update','Province_State','Country_Region','Confirmed','Deaths','Recovered','Active','Latitude','Longitude','FIPS','Admin2']]
df
# Out:
#       Last_Update Province_State                  Country_Region Confirmed  \
# 54255  2020-02-28                                     Azerbaijan         1
# 73     2020-02-24                                    Afghanistan         1
# 13109  2020-02-24                                    Afghanistan         1
# 56409  2020-03-08                                    Afghanistan         4
# 12518  2020-03-10                                    Afghanistan         5
# 12728  2020-03-11                                    Afghanistan         7
# 54561  2020-03-14                                    Afghanistan        11
# 54806  2020-03-15                                    Afghanistan        16
# 26904  2020-03-16                                    Afghanistan        21
# 26643  2020-03-17                                    Afghanistan        22
# 55503  2020-03-20                                    Afghanistan        24
# 17459  2020-03-23                                    Afghanistan        40
# 3609   2020-03-24                                    Afghanistan        74
# 7025   2020-03-25                                    Afghanistan        84
# 51197  2020-03-26                                    Afghanistan        94
# 47775  2020-03-27                                    Afghanistan       110
# 33968  2020-03-28                                    Afghanistan       110
# 30538  2020-03-29                                    Afghanistan       120
# 37882  2020-03-30                                    Afghanistan       170
# 40314  2020-03-31                                    Afghanistan       174
# 42799  2020-04-01                                    Afghanistan       237
# 9585   2020-04-02                                    Afghanistan       273
# 12210  2020-04-03                                    Afghanistan       281
# 26303  2020-04-04                                    Afghanistan       299
# 23622  2020-04-05                                    Afghanistan       349
# 53996  2020-04-06                                    Afghanistan       367
# 20950  3/22/20 23                                    Afghanistan        40
# 56438  2020-03-09                                        Albania         2
# 12494  2020-03-10                                        Albania        10
# 12703  2020-03-11                                        Albania        12
# ...           ...            ...                             ...       ...
# 30709  2020-03-29                                         Zambia        29
# 38054  2020-03-30                                         Zambia        35
# 40488  2020-03-31                                         Zambia        35
# 42973  2020-04-01                                         Zambia        36
# 55874      0         0           -19.0154    29.1549
# 17620      1         0      2  -19.015438  29.154857
# 3773       1         0      2  -19.015438  29.154857
# 7193       1         0      2  -19.015438  29.154857
# 51367      1         0      2  -19.015438  29.154857
# 47946      1         0      4  -19.015438  29.154857
# 34140      1         0      6  -19.015438  29.154857
# 30710      1         0      6  -19.015438  29.154857
# 38055      1         0      6  -19.015438  29.154857
# 40489      1         0      7  -19.015438  29.154857
# 42974      1         0      7  -19.015438  29.154857
# 9761       1         0      8  -19.015438  29.154857
# 12386      1         0      8  -19.015438  29.154857
# 26479      1         0      8  -19.015438  29.154857
# 23800      1         0      8  -19.015438  29.154857
# 54175      1         0      9  -19.015438  29.154857
# 21005      0         0      3  -19.015438  29.154857
# 12467      0         0            31.9522    35.2332
# 12809      0         0            31.9522    35.2332
#
# [54020 rows x 11 columns]

# %%
new_df = df.set_index("Country_Region")
new_df = new_df.loc[:,["Death"]]
new_df=pd.DataFrame(new_df)
new_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-59b1582c5c03> in <module>
#       1 new_df = df.set_index("Country_Region")
# ----> 2 new_df = new_df.loc[:,["Death"]]
#       3 new_df=pd.DataFrame(new_df)
#       4 new_df.head()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     886                 continue
#     887
# --> 888             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     889
#     890         return retval
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1900                     raise ValueError('Cannot index with multidimensional key')
#    1901
# -> 1902                 return self._getitem_iterable(key, axis=axis)
#    1903
#    1904             # nested tuple slicing
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1203             # A collection of keys
#    1204             keyarr, indexer = self._get_listlike_indexer(key, axis,
# -> 1205                                                          raise_missing=False)
#    1206             return self.obj._reindex_with_indexers({axis: [keyarr, indexer]},
#    1207                                                    copy=True, allow_dups=True)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1244                 raise KeyError(
#    1245                     u"None of [{key}] are in the [{axis}]".format(
# -> 1246                         key=key, axis=self.obj._get_axis_name(axis)))
#    1247
#    1248             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Death'], dtype='object')] are in the [columns]"

# %%
new_df = df.set_index("Country_Region")
new_df
# Out:
#                                Province_State Confirmed Deaths Recovered  \
# Country_Region
#  Azerbaijan                                           1      0         0
# Afghanistan                                           1      0         0
# Afghanistan                                           1      0         0
# Afghanistan                                           4      0         0
# Afghanistan                                           5      0         0
# Afghanistan                                           7      0         0
# Afghanistan                                          11      0         0
# Afghanistan                                          16      0         0
# Afghanistan                                          21      0         1
# Afghanistan                                          22      0         1
# Afghanistan                                          24      0         1
# Afghanistan                                          40      1         1
# Afghanistan                                          74      1         1
# Afghanistan                                          84      2         2
# Afghanistan                                          94      4         2
# Afghanistan                                         110      4         2
# Afghanistan                                         110      4         2
# Afghanistan                                         120      4         2
# Afghanistan                                         170      4         2
# Afghanistan                                         174      4         5
# Afghanistan                                         237      4         5
# Afghanistan                                         273      6        10
# Afghanistan                                         281      6        10
# Afghanistan                                         299      7        10
# Afghanistan                                         349      7        15
# Afghanistan                                         367     11        18
# Afghanistan                                          40      1         1
# Albania                                               2      0         0
# Albania                                              10      0         0
# Albania                                              12      1         0
# ...                                       ...       ...    ...       ...
# Zambia                                               29      0         0
# Zambia                                               35      0         0
# Zambia                                               35      0         0
# Zambia                                               36      0         0
# Zambia                                               39      1         0
# Zambia                                               39      1         2
# Zambia                                               39      1         2
# Zambia                                               39      1         3
# Zambia                                               39      1         5
# Zambia                                                3      0         0
# Zimbabwe                                              1      0         0
# Zimbabwe                                              3      0         0
# Zimbabwe                                              3      1         0
# Zimbabwe                                              3      1         0
# Zimbabwe                                              3      1         0
# Zimbabwe                                              3      1         0
# Zimbabwe                                              5      1         0
# Zimbabwe                                              7      1         0
# Zimbabwe                                              7      1         0
# Zimbabwe                                              7      1         0
# Zimbabwe                                              8      1         0
# Zimbabwe                                              8      1         0
# Zimbabwe                                              9      1         0
# Zimbabwe                                              9      1         0
# Zimbabwe                                              9      1         0
# Zimbabwe                                              9      1         0
# Zimbabwe                                             10      1         0
# Zimbabwe                                              3      0         0
# occupied Palestinian territory                       25      0         0
# occupied Palestinian territory                        0      0         0
#
#                                Active    Latitude  Longitude FIPS Admin2
# Country_Region
#  Azerbaijan
# Afghanistan
# Afghanistan                                  33.0       65.0
# Afghanistan                                  33.0       65.0
# Afghanistan                                  33.0       65.0
# Afghanistan                                  33.0       65.0
# Afghanistan                               33.9391      67.71
# Afghanistan                               33.9391      67.71
# Afghanistan                               33.9391      67.71
# Afghanistan                               33.9391      67.71
# Afghanistan                               33.9391      67.71
# Afghanistan                        38    33.93911  67.709953
# Afghanistan                        72    33.93911  67.709953
# Afghanistan                        80    33.93911  67.709953
# Afghanistan                        88    33.93911  67.709953
# Afghanistan                       104    33.93911  67.709953
# Afghanistan                       104    33.93911  67.709953
# Afghanistan                       114    33.93911  67.709953
# Afghanistan                       164    33.93911  67.709953
# Afghanistan                       165    33.93911  67.709953
# Afghanistan                       228    33.93911  67.709953
# Afghanistan                       257    33.93911  67.709953
# Afghanistan                       265    33.93911  67.709953
# Afghanistan                       282    33.93911  67.709953
# Afghanistan                       327    33.93911  67.709953
# Afghanistan                       338    33.93911  67.709953
# Afghanistan                        38    33.93911  67.709953
# Albania                                   41.1533    20.1683
# Albania                                   41.1533    20.1683
# Albania                                   41.1533    20.1683
# ...                               ...         ...        ...  ...    ...
# Zambia                             29  -13.133897  27.849332
# Zambia                             35  -13.133897  27.849332
# Zambia                             35  -13.133897  27.849332
# Zambia                             36  -13.133897  27.849332
# Zambia                             38  -13.133897  27.849332
# Zambia                             36  -13.133897  27.849332
# Zambia                             36  -13.133897  27.849332
# Zambia                             35  -13.133897  27.849332
# Zambia                             33  -13.133897  27.849332
# Zambia                              3  -13.133897  27.849332
# Zimbabwe                                    -20.0       30.0
# Zimbabwe                                 -19.0154    29.1549
# Zimbabwe                            2  -19.015438  29.154857
# Zimbabwe                            2  -19.015438  29.154857
# Zimbabwe                            2  -19.015438  29.154857
# Zimbabwe                            2  -19.015438  29.154857
# Zimbabwe                            4  -19.015438  29.154857
# Zimbabwe                            6  -19.015438  29.154857
# Zimbabwe                            6  -19.015438  29.154857
# Zimbabwe                            6  -19.015438  29.154857
# Zimbabwe                            7  -19.015438  29.154857
# Zimbabwe                            7  -19.015438  29.154857
# Zimbabwe                            8  -19.015438  29.154857
# Zimbabwe                            8  -19.015438  29.154857
# Zimbabwe                            8  -19.015438  29.154857
# Zimbabwe                            8  -19.015438  29.154857
# Zimbabwe                            9  -19.015438  29.154857
# Zimbabwe                            3  -19.015438  29.154857
# occupied Palestinian territory            31.9522    35.2332
# occupied Palestinian territory            31.9522    35.2332
#
# [54020 rows x 9 columns]

# %%
df.to_csv("clean_data.csv")
