# %%
import pandas as pd
import os, sys
import glob
import numpy as np

# %%
path = "csse_covid_19_data/csse_covid_19_daily_reports"
all_files = glob.glob(path + "/*.csv")
li = []
for filename in all_files:
    df = pd.read_csv(filename, encoding="ISO-8859-1")
    li.append(df)
    frame = pd.concat(li, axis=0, ignore_index=True, sort=False)

# %%
frame.count()
# Out:
# Province/State     4358
# Country/Region     7617
# Last Update        7617
# Confirmed         56785
# Deaths            56363
# Recovered         56416
# FIPS              44680
# Admin2            45054
# Province_State    46424
# Country_Region    49187
# Last_Update       49187
# Lat               48901
# Long_             48901
# Active            49187
# Combined_Key      49187
# Latitude           4799
# Longitude          4799
# dtype: int64

# %%
df = frame
df = df.fillna('')
df['Province_State'] = df['Province/State'].astype(str) + df['Province_State'].astype(str)
df['Country_Region'] = df['Country/Region'].astype(str) + df['Country_Region'].astype(str)
df['Last_Update'] = df['Last Update'].astype(str) + df['Last_Update'].astype(str)
df['Latitude'] = df['Latitude'].astype(str) + df['Lat'].astype(str)
df['Longitude'] = df['Longitude'].astype(str) + df['Long_'].astype(str)
df = df.drop(columns=['Province/State','Country/Region','Last Update','Lat','Long_','Combined_Key'])
df['Last_Update'] = df['Last_Update'].str[0:10]
df = df.sort_values(by=['Country_Region','Last_Update'])
df.drop_duplicates(keep='first', inplace=True)
df = df[['Province_State','Country_Region','Confirmed','Deaths','Recovered','Active','Latitude','Longitude','FIPS','Admin2']]
df
# Out:
#       Province_State                  Country_Region Confirmed Deaths  \
# 54255                                     Azerbaijan         1      0
# 73                                       Afghanistan         1      0
# 13109                                    Afghanistan         1      0
# 56409                                    Afghanistan         4      0
# 12518                                    Afghanistan         5      0
# ...              ...                             ...       ...    ...
# 23800                                       Zimbabwe         9      1
# 54175                                       Zimbabwe        10      1
# 21005                                       Zimbabwe         3      0
# 12467                 occupied Palestinian territory        25      0
# 12809                 occupied Palestinian territory         0      0
#
#       Recovered Active    Latitude  Longitude FIPS Admin2
# 54255         0
# 73            0
# ...

# %%
new_df = df.set_index("Country_Region")
new_df = new_df.loc[:,["Death"]]
new_df=pd.DataFrame(new_df)
new_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-59b1582c5c03> in <module>
#       1 new_df = df.set_index("Country_Region")
# ----> 2 new_df = new_df.loc[:,["Death"]]
#       3 new_df=pd.DataFrame(new_df)
#       4 new_df.head()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     820                 continue
#     821
# --> 822             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     823
#     824         return retval
#
# ...

# %%
df.to_csv("clean_data.csv")
