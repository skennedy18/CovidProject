# %%
import requests
import pandas as pd
import matplotlib as plt
import json

# %%
response = requests.get('https://www.dph.illinois.gov/sitefiles/COVIDZip.json?nocache=1')

data = response.json()
zip_data= pd.json_normalize(data['zip_values'])
test= pd.DataFrame(data[''])
# Out:
#        zip  confirmed_cases  \
# 0    60002               26
# 1    60004               88
# 2    60005               32
# 3    60007               45
# 4    60008               25
# ..     ...              ...
# 352  62702               11
# 353  62711                8
# 354  62801               29
# 355  62901               27
# 356  62959                6
#
#                                       demographics.age  \
# 0    [{'age_group': 'Unknown', 'count': 0}, {'age_g...
# 1    [{'age_group': 'Unknown', 'count': 0}, {'age_g...
# 2    [{'age_group': 'Unknown', 'count': 0}, {'age_g...
# 3    [{'age_group': 'Unknown', 'count': 0}, {'age_g...
# 4    [{'age_group': 'Unknown', 'count': 0}, {'age_g...
# ..                                                 ...
# 352  [{'age_group': 'Unknown', 'count': 0}, {'age_g...
# 353  [{'age_group': 'Unknown', 'count': 0}, {'age_g...
# 354  [{'age_group': 'Unknown', 'count': 0}, {'age_g...
# 355  [{'age_group': 'Unknown', 'count': 0}, {'age_g...
# 356  [{'age_group': 'Unknown', 'count': 0}, {'age_g...
#
#                                      demographics.race  \
# 0    [{'description': 'White', 'count': 7}, {'descr...
# 1    [{'description': 'White', 'count': 20}, {'desc...
# 2    [{'description': 'White', 'count': 7}, {'descr...
# 3    [{'description': 'White', 'count': 20}, {'desc...
# 4    [{'description': 'White', 'count': 13}, {'desc...
# ..                                                 ...
# 352  [{'description': 'White', 'count': 6}, {'descr...
# 353  [{'description': 'White', 'count': 0}, {'descr...
# 354  [{'description': 'White', 'count': 7}, {'descr...
# 355  [{'description': 'White', 'count': 6}, {'descr...
# 356  [{'description': 'White', 'count': 0}, {'descr...
#
#                                    demographics.gender
# 0    [{'description': 'Male', 'count': 13}, {'descr...
# 1    [{'description': 'Male', 'count': 27}, {'descr...
# 2    [{'description': 'Male', 'count': 17}, {'descr...
# 3    [{'description': 'Male', 'count': 23}, {'descr...
# 4    [{'description': 'Male', 'count': 14}, {'descr...
# ..                                                 ...
# 352  [{'description': 'Male', 'count': 0}, {'descri...
# 353  [{'description': 'Male', 'count': 0}, {'descri...
# 354  [{'description': 'Male', 'count': 6}, {'descri...
# 355  [{'description': 'Male', 'count': 8}, {'descri...
# 356  [{'description': 'Male', 'count': 0}, {'descri...
#
# [357 rows x 5 columns]
