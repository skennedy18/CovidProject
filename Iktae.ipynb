# %%
import pandas as pd
import os, sys
import glob
import numpy as np

# %%
path = "csse_covid_19_data/csse_covid_19_daily_reports"
all_files = glob.glob(path + "/*.csv")
li = []
for filename in all_files:
    df = pd.read_csv(filename, encoding="ISO-8859-1")
    li.append(df)
    frame = pd.concat(li, axis=0, ignore_index=True, sort=False)

# %%
df = frame
df = df.fillna('')
df['Province_State'] = df['Province/State'].astype(str) + df['Province_State'].astype(str)
df['Country_Region'] = df['Country/Region'].astype(str) + df['Country_Region'].astype(str)
df['Last_Update'] = df['Last Update'].astype(str) + df['Last_Update'].astype(str)
df['Latitude'] = df['Latitude'].astype(str) + df['Lat'].astype(str)
df['Longitude'] = df['Longitude'].astype(str) + df['Long_'].astype(str)
df = df.drop(columns=['Province/State','Country/Region','Last Update','Lat','Long_','Combined_Key'])
df['Last_Update'] = df['Last_Update'].str[0:10]
df = df.sort_values(by=['Country_Region','Last_Update'])
df.drop_duplicates(keep='first', inplace=True)
df = df[['Province_State','Country_Region','Last_Update','Confirmed','Deaths','Recovered','Active','Latitude','Longitude','FIPS','Admin2']]
# df

# %%
sanfran = df.loc[df['Province_State'].str.contains("San Francisco") | df["Admin2"].str.contains("San Francisco")]
sanfran['name'] = "San Francisco"
sanfran["Latitude"] = 37.75215114
sanfran["Longitude"] = -122.4385672
tampa = df.loc[df['Province_State'].str.contains("Florida") & df["Admin2"].str.contains("Hillsborough")]
tampa['name'] = "Tampa"
tampa["Latitude"] = 27.9276559
tampa["Longitude"] = -82.32013172
chi = df.loc[df['Province_State'].str.contains("Illinois") & df["Admin2"].str.contains("Cook")]
chi['name'] = "Chicago"
chi["Latitude"] = 41.84144849
chi["Longitude"] = -87.81658794
nyc = df.loc[df['Province_State'].str.contains("New York City") | df["Admin2"].str.contains("New York City")]
nyc["Latitude"] = 40.7672726
nyc["Longitude"] = -73.97152637
nyc['name'] = "New York City"
htown = df.loc[df['Province_State'].str.contains("Texas") & df["Admin2"].str.contains("Houston")]
htown["Latitude"] = 31.31925973
htown["Longitude"] = -95.42226208
htown['name'] = "Houston"
det = df.loc[df['Province_State'].str.contains("Michigan") & df["Admin2"].str.contains("Wayne")]
det["Latitude"] = 42.28098405
det["Longitude"] = -83.281255
det['name'] = "Detroit"
sea = df.loc[df['Province_State'].str.contains("Washington") & df["Admin2"].str.contains("King")]
sea["Latitude"] = 47.49137892
sea["Longitude"] = -121.8346131
sea['name'] = "Seattle"
bos = df.loc[df['Province_State'].str.contains("Massachusetts") & df["Admin2"].str.contains("Suffolk")]
bos["Latitude"] = 42.3279514
bos["Longitude"] = -71.07850442
bos['name'] = "Boston"
mil = df.loc[df['Province_State'].str.contains("Wisconsin") & df["Admin2"].str.contains("Milwaukee")]
mil["Latitude"] = 43.00486062
mil["Longitude"] = -87.96733172
mil['name'] = "Milwaukee"
tor = df.loc[df['Province_State'].str.contains("Ontario")]
tor["Latitude"] = 51.2538
tor["Longitude"] = -85.3232
tor['name'] = "Toronto"
ita = df.loc[df['Country_Region'].str.contains("Italy")]
ita["Latitude"] = 41.87194
ita["Longitude"] = 12.56738
ita['name'] = "Italy"
spa = df.loc[df['Country_Region'].str.contains("Spain")]
spa["Latitude"] = 40.4637
spa["Longitude"] = -3.7492
spa['name'] = "Spain"
fra = df.loc[df['Country_Region'].str.contains("France")]
fra = fra.replace("","France")
fra = fra.loc[fra['Province_State'].str.contains("France")]
fra["Latitude"] = 46.2276
fra["Longitude"] = 2.2137
fra['name'] = "France"
ger = df.loc[df['Country_Region'].str.contains("Germany")]
ger['name'] = "Germany"
ger = ger.drop(ger[ger["Province_State"] == "Bavaria"].index)
ger["Latitude"] = 51.1657
ger["Longitude"] = 10.4515
uk = df.loc[df['Country_Region'].str.contains("United Kingdom")]
uk = uk.replace("","United Kingdom")
uk = uk.loc[uk['Province_State'].str.contains("United Kingdom")]
uk['name'] = "United Kingdom"
uk["Latitude"] = 55.3781
uk["Longitude"] = -3.436
nor = df.loc[df['Country_Region'].str.contains("Norway")]
nor['name'] = "Norway"
nor["Latitude"] = 60.472
nor["Longitude"] = 8.4689
swe = df.loc[df['Country_Region'].str.contains("Sweden")]
swe['name'] = "Sweden"
swe["Latitude"] = 60.1282
swe["Longitude"] = 18.6435
ira = df.loc[df['Country_Region'].str.contains("Iran")]
ira['name'] = "Iran"
ira["Latitude"] = 32.4279
ira["Longitude"] = 53.688
tur = df.loc[df['Country_Region'].str.contains("Turkey")]
tur['name'] = "Turkey"
tur["Latitude"] = 38.9637
tur["Longitude"] = 35.2433
beijing = df.loc[df['Province_State'].str.contains("Beijing")]
beijing['name'] = "Beijing"
beijing["Latitude"] = 40.1824
beijing["Longitude"] = 116.4142
hubei = df.loc[df['Province_State'].str.contains("Hubei")]
hubei['name'] = "Hubei"
hubei["Latitude"] = 30.9756
hubei["Longitude"] = 112.2707
kor = df.loc[df['Country_Region'].str.contains("Korea")]
kor['name'] = "South Korea"
kor["Latitude"] = 35.907757
kor["Longitude"] = 127.766922
mal = df.loc[df['Country_Region'].str.contains("Malaysia")]
mal['name'] = "Malaysia"
mal["Latitude"] = 4.210484
mal["Longitude"] = 101.975766
syd = df.loc[df['Country_Region'].str.contains("Australia") & df['Province_State'].str.contains("New South Wales")]
syd["Latitude"] = -33.8688
syd["Longitude"] = 151.2093
syd['name'] = "Sydney"
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
merged_df = pd.concat([sanfran, tampa, chi, nyc, htown, det, sea, bos, mil, tor, ita, spa, fra, ger, uk, nor, swe, ira, tur, beijing, hubei, kor, mal, syd])
merged_df
# Out:
#                  Province_State Country_Region Last_Update Confirmed Deaths  \
# 13315  San Francisco County, CA             US  2020-03-05         2      0
# 13048  San Francisco County, CA             US  2020-03-07         9      0
# 56386  San Francisco County, CA             US  2020-03-08         9      0
# 16715                California             US  2020-03-23       131      0
# 2866                 California             US  2020-03-24       152      0
# 6283                 California             US  2020-03-25       178      1
# 50455                California             US  2020-03-26       223      2
# 47026                California             US  2020-03-27       279      3
# 33219                California             US  2020-03-28       308      4
# 29785                California             US  2020-03-29       340      4
# 37125                California             US  2020-03-30       374      6
# ...

# %%
merged_df = merged_df.drop(columns=['Province_State','Country_Region','Admin2','FIPS'])
merged_df
# Out:
#       Last_Update Confirmed Deaths Recovered Active   Latitude   Longitude  \
# 13315  2020-03-05         2      0         0         37.752151 -122.438567
# 13048  2020-03-07         9      0         0         37.752151 -122.438567
# 56386  2020-03-08         9      0         0         37.752151 -122.438567
# 16715  2020-03-23       131      0         0      0  37.752151 -122.438567
# 2866   2020-03-24       152      0         0      0  37.752151 -122.438567
# 6283   2020-03-25       178      1         0      0  37.752151 -122.438567
# 50455  2020-03-26       223      2         0      0  37.752151 -122.438567
# 47026  2020-03-27       279      3         0      0  37.752151 -122.438567
# 33219  2020-03-28       308      4         0      0  37.752151 -122.438567
# 29785  2020-03-29       340      4         0      0  37.752151 -122.438567
# 37125  2020-03-30       374      6         0      0  37.752151 -122.438567
# ...

# %%
merged_df.to_csv("selected_city.csv")

# %%
merged_df.loc[merged_df['Last_Update'].str.contains("3/22/20"), 'Last_Update'] = "2020-03-22"
merged_df.loc[merged_df['Last_Update'].str.contains("1/23/20"), 'Last_Update'] = "2020-01-23"
merged_df.loc[merged_df['Last_Update'].str.contains("1/24/20"), 'Last_Update'] = "2020-01-24"
merged_df.loc[merged_df['Last_Update'].str.contains("1/25/20"), 'Last_Update'] = "2020-01-25"
merged_df.loc[merged_df['Last_Update'].str.contains("1/26/20"), 'Last_Update'] = "2020-01-26"
merged_df.loc[merged_df['Last_Update'].str.contains("1/27/20"), 'Last_Update'] = "2020-01-27"
merged_df.loc[merged_df['Last_Update'].str.contains("1/28/20"), 'Last_Update'] = "2020-01-28"
merged_df.loc[merged_df['Last_Update'].str.contains("1/29/20"), 'Last_Update'] = "2020-01-29"
merged_df.loc[merged_df['Last_Update'].str.contains("1/30/20"), 'Last_Update'] = "2020-01-30"
merged_df.loc[merged_df['Last_Update'].str.contains("2/1/2020"), 'Last_Update'] = "2020-02-01"
merged_df = merged_df.sort_values(by=['name','Last_Update'])
merged_df
# Out:
#       Last_Update Confirmed Deaths Recovered          Active Latitude  \
# 43424  1/22/2020         14
# 13937  1/31/2020        139      1         5
# 43462  2020-01-23        22
# 54964  2020-01-24        36                1
# 54922  2020-01-25        41                2
# 27185  2020-01-26        68                2
# 27232  2020-01-27        80      1         2
# 44421  2020-01-28        91      1         4
# 44472  2020-01-29       111      1         4
# 13999  2020-01-30       114      1         4
# 56228  2020-02-01       168      1         9
# 13802  2020-02-02       191      1         9
# 13869  2020-02-03       212      1        12
# 13463  2020-02-04       228      1        23
# 13392  2020-02-05       253      1        24
# 34485  2020-02-06       274      1        31
# 34556  2020-02-07       297      1        33
# 13533  2020-02-08       315      2        34
# 13605  2020-02-09       326      2        37
# 43591  2020-02-10       337      2        44
# ...

# %%
merged_df.to_csv("selected_city.csv")

# %%
beijing
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       Province_State  Country_Region Last_Update Confirmed Deaths Recovered  \
# 12620        Beijing           China  2020-03-11       435      8       326
# 43232        Beijing           China  2020-03-12       435      8       334
# ...

# %%
fra = df.loc[df['Country_Region'].str.contains("France")]
fra['Coutry_Region'] = fra['Country_Region'].replace("","France")
fra = fra.loc[fra['Province_State'].str.contains("France")]
fra
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       Province_State Country_Region Last_Update Confirmed Deaths Recovered  \
# 12598         France         France  2020-03-11      2281     48        12
# 43054         France         France  2020-03-11      3661     79        12
# 54416         France         France  2020-03-14      4469     91        12
# 54665         France         France  2020-03-15      4499     91        12
# 26763         France         France  2020-03-16      6633    148        12
# 26487         France         France  2020-03-17      7652    148        12
# 44133         France         France  2020-03-18      9043    148        12
# ...
