# %%
import pandas as pd
import os, sys
import glob
import numpy as np

# %%
path = "csse_covid_19_data/csse_covid_19_daily_reports"
all_files = glob.glob(path + "/*.csv")
li = []
for filename in all_files:
    df = pd.read_csv(filename, encoding="ISO-8859-1")
    li.append(df)
    frame = pd.concat(li, axis=0, ignore_index=True, sort=False)

# %%
frame.count()
# Out:
# Province/State     4358
# Country/Region     7617
# Last Update        7617
# Confirmed         56785
# Deaths            56363
# Recovered         56416
# FIPS              44680
# Admin2            45054
# Province_State    46424
# Country_Region    49187
# Last_Update       49187
# Lat               48901
# Long_             48901
# Active            49187
# Combined_Key      49187
# Latitude           4799
# Longitude          4799
# dtype: int64

# %%
df = frame
df = df.fillna('')
df['Province_State'] = df['Province/State'].astype(str) + df['Province_State'].astype(str)
df['Country_Region'] = df['Country/Region'].astype(str) + df['Country_Region'].astype(str)
df['Last_Update'] = df['Last Update'].astype(str) + df['Last_Update'].astype(str)
df['Latitude'] = df['Latitude'].astype(str) + df['Lat'].astype(str)
df['Longitude'] = df['Longitude'].astype(str) + df['Long_'].astype(str)
df = df.drop(columns=['Province/State','Country/Region','Last Update','Lat','Long_','Combined_Key'])
df['Last_Update'] = df['Last_Update'].str[0:10]
df = df.sort_values(by=['Country_Region','Last_Update'])
df.drop_duplicates(keep='first', inplace=True)
df = df[['Province_State','Country_Region','Last_Update','Confirmed','Deaths','Recovered','Active','Latitude','Longitude','FIPS','Admin2']]
df
# Out:
#       Province_State                  Country_Region Last_Update Confirmed  \
# 54255                                     Azerbaijan  2020-02-28         1
# 73                                       Afghanistan  2020-02-24         1
# 13109                                    Afghanistan  2020-02-24         1
# 56409                                    Afghanistan  2020-03-08         4
# 12518                                    Afghanistan  2020-03-10         5
# 12728                                    Afghanistan  2020-03-11         7
# 54561                                    Afghanistan  2020-03-14        11
# 54806                                    Afghanistan  2020-03-15        16
# 26904                                    Afghanistan  2020-03-16        21
# 26643                                    Afghanistan  2020-03-17        22
# 55503                                    Afghanistan  2020-03-20        24
# 17459                                    Afghanistan  2020-03-23        40
# 3609                                     Afghanistan  2020-03-24        74
# 7025                                     Afghanistan  2020-03-25        84
# 51197                                    Afghanistan  2020-03-26        94
# 47775                                    Afghanistan  2020-03-27       110
# 33968                                    Afghanistan  2020-03-28       110
# 30538                                    Afghanistan  2020-03-29       120
# 37882                                    Afghanistan  2020-03-30       170
# 40314                                    Afghanistan  2020-03-31       174
# 42799                                    Afghanistan  2020-04-01       237
# 9585                                     Afghanistan  2020-04-02       273
# 12210                                    Afghanistan  2020-04-03       281
# 26303                                    Afghanistan  2020-04-04       299
# 23622                                    Afghanistan  2020-04-05       349
# 53996                                    Afghanistan  2020-04-06       367
# 20950                                    Afghanistan  3/22/20 23        40
# 56438                                        Albania  2020-03-09         2
# 12494                                        Albania  2020-03-10        10
# 12703                                        Albania  2020-03-11        12
# ...              ...                             ...         ...       ...
# 30709                                         Zambia  2020-03-29        29
# 38054                                         Zambia  2020-03-30        35
# 40488                                         Zambia  2020-03-31        35
# 42973                                         Zambia  2020-04-01        36
# 9760                                          Zambia  2020-04-02        39
# 12385                                         Zambia  2020-04-03        39
# 26478                                         Zambia  2020-04-04        39
# 23799                                         Zambia  2020-04-05        39
# 54174                                         Zambia  2020-04-06        39
# 21004                                         Zambia  3/22/20 23         3
# 55606                                       Zimbabwe  2020-03-20         1
# 55874                                       Zimbabwe  2020-03-21         3
# 17620                                       Zimbabwe  2020-03-23         3
# 3773                                        Zimbabwe  2020-03-24         3
