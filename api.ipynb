# %%
import pandas as pd
import os, sys
import glob
import numpy as np
import time
import datetime

# %%
df = pd.read_csv("data_manual.csv", encoding="ISO-8859-1")
df
# Out:
#                          Name        Lat        Long  1/22/2020   1/23/2020  \
# 0    San Francisco,California  37.752151 -122.438567        0.0    0.000000
# 1    San Francisco,California        NaN         NaN        0.0    0.000000
# 2    San Francisco,California        NaN         NaN        NaN         NaN
# 3        Hillsborough,Florida  27.927656  -82.320132        0.0    0.000000
# 4        Hillsborough,Florida        NaN         NaN        0.0    0.000000
# 5        Hillsborough,Florida        NaN         NaN        NaN         NaN
# 6               Cook,Illinois  41.841448  -87.816588        0.0    0.000000
# 7               Cook,Illinois        NaN         NaN        0.0    0.000000
# 8               Cook,Illinois        NaN         NaN        NaN         NaN
# 9           New York,New York  40.767273  -73.971526        0.0    0.000000
# 10          New York,New York        NaN         NaN        0.0    0.000000
# ...

# %%
s = "1/23/2020"
time.mktime(datetime.datetime.strptime(s, "%m/%d/%Y").timetuple())
# Out:
# 1579755600.0

# %%
http://history.openweathermap.org/data/2.5/history/city?lat={lat}&lon={lon}&type=hour&start={start}&cnt={cnt}&appid={YOUR_API_KEY}
# Out:
# 86400.0

# %%
for i, row in df.iterrows():
    if i%3 == 2:
        print(row[3:])
# Out:
# 1/22/2020    NaN
# 1/23/2020    NaN
# 1/24/2020    NaN
# 1/25/2020    NaN
# 1/26/2020    NaN
# 1/27/2020    NaN
# 1/28/2020    NaN
# 1/29/2020    NaN
# 1/30/2020    NaN
# 1/31/2020    NaN
# 2/1/2020     NaN
# 2/2/2020     NaN
# 2/3/2020     NaN
# 2/4/2020     NaN
# 2/5/2020     NaN
# 2/6/2020     NaN
# 2/7/2020     NaN
# 2/8/2020     NaN
# 2/9/2020     NaN
# 2/10/2020    NaN
# 2/11/2020    NaN
# 2/12/2020    NaN
# 2/13/2020    NaN
# 2/14/2020    NaN
# 2/15/2020    NaN
# 2/16/2020    NaN
# 2/17/2020    NaN
# 2/18/2020    NaN
# 2/19/2020    NaN
# 2/20/2020    NaN
#             ...
# 3/17/2020    NaN
# 3/18/2020    NaN
# 3/19/2020    NaN
# 3/20/2020    NaN
# 3/21/2020    NaN
# 3/22/2020    NaN
# 3/23/2020    NaN
# 3/24/2020    NaN
# 3/25/2020    NaN
# 3/26/2020    NaN
# 3/27/2020    NaN
# 3/28/2020    NaN
# 3/29/2020    NaN
# 3/30/2020    NaN
# 3/31/2020    NaN
# 4/1/2020     NaN
# 4/2/2020     NaN
# 4/3/2020     NaN
# 4/4/2020     NaN
# 4/5/2020     NaN
# 4/6/2020     NaN
# ...
